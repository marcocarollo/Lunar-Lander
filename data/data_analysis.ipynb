# %%
import pandas as pd

# %% [markdown]
# Simple notebook to read and sort the results according to the best score.

# %%
# Read the data from file using read_csv
MC = pd.read_csv('./Fixed_t/MC_results.csv')
SARSA = pd.read_csv('./Fixed_t/SARSA_results.csv')
ESARSA = pd.read_csv('./Fixed_t/ESARSA_results.csv')
Q = pd.read_csv('./Fixed_t/Q_results.csv')

# %%
MC.sort_values("mean", ascending=False)
# Out:
#        k_epsilon  epsilon_0  cumulative_mean       mean         std  \
# 6   1.000000e-07       0.20       -38.403587  33.333181  108.369116
# 1   1.000000e-06       0.50       -50.056031  23.758219  100.731299
# 4   1.000000e-05       0.50       -27.103739  13.617490   92.254672
# 11  1.000000e-06       0.10       -29.028073   6.804415  104.893484
# 14  1.000000e-07       0.05       -35.334696  -0.207560   86.031398
# 10  1.000000e-07       0.10       -39.959499  -3.108007   78.734151
# 2   1.000000e-07       0.50       -70.121148  -5.286884   63.521180
# 9   1.000000e-04       0.20       -28.436376  -9.871726   84.998999
# 7   1.000000e-06       0.20       -44.994142 -10.946796   67.160160
# 3   1.000000e-06       0.50       -54.705845 -12.526243   49.413493
# 0   1.000000e-07       0.50       -69.054048 -21.736943   68.624218
# 15  1.000000e-06       0.05       -43.955077 -21.887525   47.520850
# 8   1.000000e-05       0.20       -43.179691 -24.081783   47.378199
# ...

# %%
SARSA.sort_values("mean", ascending=False)
# Out:
#     lambda       k_alpha     k_epsilon  epsilon_0  cumulative_mean  \
# 10     0.5  1.000000e-04  1.000000e-04        0.2        60.144369
# 11     0.8  1.000000e-04  1.000000e-04        0.2        50.234949
# 3      0.0  1.000000e-07  1.000000e-04        0.2        43.011435
# 16     0.5  1.000000e-07  1.000000e-04        0.5        26.900759
# 7      0.5  1.000000e-04  1.000000e-07        0.2        27.289178
# 4      0.5  1.000000e-07  1.000000e-04        0.2        73.183513
# 22     0.5  1.000000e-04  1.000000e-04        0.5        24.914867
# 15     0.0  1.000000e-07  1.000000e-04        0.5        13.711038
# 23     0.8  1.000000e-04  1.000000e-04        0.5        10.694508
# 5      0.8  1.000000e-07  1.000000e-04        0.2        38.610030
# 17     0.8  1.000000e-07  1.000000e-04        0.5       -21.741410
# 1      0.5  1.000000e-07  1.000000e-07        0.2         5.031405
# 9      0.0  1.000000e-04  1.000000e-04        0.2       -14.460025
# ...

# %%
ESARSA.sort_values("mean", ascending=False)
# Out:
#          k_alpha  k_epsilon  epsilon_0  cumulative_mean        mean  \
# 5   5.000000e-06   0.000005        0.2        46.077236  163.010306
# 4   1.000000e-07   0.000005        0.2        36.176974  159.590752
# 1   1.000000e-07   0.000001        0.2        -3.839794  158.035587
# 19  1.000000e-07   0.000010        0.5        -0.088034  147.079115
# 8   5.000000e-06   0.000010        0.2        48.145591  143.912165
# 7   1.000000e-07   0.000010        0.2        32.534522  134.380783
# 11  5.000000e-06   0.000100        0.2        39.578923  127.094647
# 22  1.000000e-07   0.000100        0.5        10.755009  125.342009
# 17  5.000000e-06   0.000005        0.5       -23.574232  125.218330
# 23  5.000000e-06   0.000100        0.5        -4.254366  108.897237
# 20  5.000000e-06   0.000010        0.5         5.041838  105.230052
# 12  1.000000e-04   0.000100        0.2        10.406630   87.824704
# 10  1.000000e-07   0.000100        0.2        30.555158   86.509128
# ...

# %%
Q.sort_values("mean", ascending=False)
# Out:
#     lambda       k_alpha     k_epsilon  epsilon_0  cumulative_mean  \
# 11     0.5  1.000000e-04  1.000000e-04        0.2        94.361552
# 10     0.5  1.000000e-07  1.000000e-04        0.2        74.694654
# 2      0.0  1.000000e-07  1.000000e-04        0.2        55.156959
# 6      0.0  1.000000e-07  1.000000e-04        0.5        -0.785486
# 9      0.5  1.000000e-04  1.000000e-07        0.2        16.666952
# 23     0.8  1.000000e-04  1.000000e-04        0.5        -3.522195
# 15     0.5  1.000000e-04  1.000000e-04        0.5         3.111552
# 19     0.8  1.000000e-04  1.000000e-04        0.2        35.175946
# 14     0.5  1.000000e-07  1.000000e-04        0.5        -4.610794
# 18     0.8  1.000000e-07  1.000000e-04        0.2         9.038056
# 3      0.0  1.000000e-04  1.000000e-04        0.2        32.386541
# 7      0.0  1.000000e-04  1.000000e-04        0.5       -19.096662
# 17     0.8  1.000000e-04  1.000000e-07        0.2       -16.595862
# ...
